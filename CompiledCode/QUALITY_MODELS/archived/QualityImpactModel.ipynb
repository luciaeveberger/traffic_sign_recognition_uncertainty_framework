# %% [markdown]
# # POC QIM descision Tree
#
# -- identifies the classes of interest for the tree

# %%
import pandas as pd
import numpy as np
import random 
from ast import literal_eval
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, balanced_accuracy_score
from sklearn.utils import shuffle
from tabulate import tabulate
import pickle


import pydotplus
from sklearn.datasets import load_iris
from sklearn import tree
import numpy
from IPython.display import Image, display
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import os
root_directory = os.path.dirname(os.getcwd())

# %% [markdown]
# # If google colab is used

# %%
from google.colab import drive
drive.mount('/content/gdrive')
import zipfile
root_path = 'gdrive/My Drive/data_output/TSD/'
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-d25942adec7c> in <module>
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/gdrive')
#       3 import zipfile
#       4 root_path = 'gdrive/My Drive/data_output/TSD/'
#
# ModuleNotFoundError: No module named 'google.colab'

# %% [markdown]
# # Process the input data
#
# -- can be used via a dataframe csv
# -- can be used via a p file

# %%
from sklearn.model_selection import train_test_split

def generate_ds():
    subset = df[['DARKNESS_classes','RAIN_classes', 'MOTIONBLUR_classes', 'BACKLIGHTSUN_classes']]
    
    X = subset.values
    y = df['VGG_is_correct'].astype(int).values
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=33)
    X_train, y_train = shuffle(X_train, y_train)
    X_test, y_test = shuffle(X_test, y_test)
    data_set = {"data":X_train, 
                "feature_names":['DARKNESS', 'RAIN', 'MOTIONBLUR', 'BACKLIGHTSUN'],
                "target_names":"",
                "target":y_train}
    return data_set, X_test, y_test

def generate_ds_from_p_file(pickle_file_path):
    with open (pickle_file_path, mode='rb') as f:
        annotated_data = pickle.load(f)
    X = np.array(list(zip(
                annotated_data['BACKLIGHT'], 
                 annotated_data['DARKNESS'], 
                 annotated_data['DIRTLENS'], 
                 annotated_data['MOTIONBLUR'], 
                 annotated_data['RAIN'])))
    y = np.array(annotated_data['VGG_is_correct'], dtype=np.int)
    
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.01, random_state=33)
    X_train, y_train = shuffle(X_train, y_train)
    X_test, y_test = shuffle(X_test, y_test)
    data_set = {"data":X_train, 
                "feature_names":['BACKLIGHSUN', 
                                 'DARKNESS', 
                                 'DIRTLENS', 
                                 'MOTIONBLUR', 
                                 'RAIN'],
                "target_names":"",
                "target":y_train}

    return data_set, X_test, y_test

# %% [markdown]
# # Generate Classifying Descision Tree

# %%
class DT:
    def __init__(self, dataset):
        self.dataset = dataset
        #self.class_names = class_names
        self.clf = self.train_model()

    def train_model(self):
        """
        Train decision tree classifier

        :param iris:    iris data set instance
        :return:        classifier instance
        """
        clf = tree.DecisionTreeClassifier("gini", 
                                          max_features=None, max_leaf_nodes=15, 
                                          min_samples_leaf=10,
            min_samples_split=2, min_weight_fraction_leaf=0.0,
            presort=False, random_state=None) #splitter='random')
        
        clf = clf.fit(self.dataset['data'], self.dataset['target'])
        
        return clf

    def display_image(self, file_path):
        """
        Displays the decision tree image

        :param clf:     classifier instance
        :param iris:    iris data set instance
        """
        dot_data = tree.export_graphviz(self.clf,
                                        feature_names= self.dataset['feature_names'],
                                        class_names=["0","1"],
                                        filled=False, rounded=False)

        graph = pydotplus.graph_from_dot_data(dot_data)
        display(Image(data=graph.create_png()))
        graph.write_pdf(file_path)


if __name__ == '__main__':
    pickle_file = root_directory + "/TSD/validation_p_files/VALIDATION_ANNOTATED.p"    
    context_data, X_test, y_test = generate_ds_from_p_file(pickle_file)
    dt = DT(context_data)
    dt.display_image("original_tree.pdf")
    y_pred = dt.clf.predict(X_test)
    print("Model Accuracy: %.2f" % (accuracy_score(y_test,y_pred)*100), "%")
    from sklearn.metrics import classification_report, confusion_matrix  
    #print(confusion_matrix(y_test, y_pred))  
    #print(classification_report(y_test, y_pred))
# Out:
# Model Accuracy: 88.20 %

# %%
from sklearn.metrics import roc_curve, auc
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(false_positive_rate, true_positive_rate)
roc_auc
# Out:
# 0.4944852941176471

# %%
from sklearn import metrics
def measure_performance(X,y,clf, show_accuracy=True, show_classification_report=True, show_confusion_matrix=True):
    y_pred=clf.predict(X)   
    print(len(X))
    if show_accuracy:
        print ("Accuracy:{0:.3f}".format(metrics.accuracy_score(y,y_pred)),"\n")

    if show_classification_report:
        print ("Classification report")
        print (metrics.classification_report(y,y_pred),"\n")
        
    if show_confusion_matrix:
        print ("Confusion matrix")
        print (metrics.confusion_matrix(y,y_pred),"\n")
        
measure_performance(context_data['data'],context_data['target'],dt.clf, show_classification_report=True, show_confusion_matrix=True)
# Out:
# 30175
# Accuracy:0.852
#
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.53      0.04      0.07      4494
#            1       0.86      0.99      0.92     25681
#
#    micro avg       0.85      0.85      0.85     30175
#    macro avg       0.69      0.52      0.50     30175
# weighted avg       0.81      0.85      0.79     30175
#
#
# Confusion matrix
# [[  176  4318]
#  [  155 25526]]

# %% [markdown]
# # Feature Importance by Relevance

# %%
from sklearn.model_selection import cross_val_score, LeaveOneOut
from scipy.stats import sem

print(dt.clf.feature_importances_)
# Out:
# [0.06748403 0.04716262 0.04024329 0.18114303 0.66396704]

# %% [markdown]
# # Analyse the Results of the DT tree
# -- find Entropy (information gain splits)
# -- use prediction to make a table of the predictions

# %%
def calculate_metrics(trained_model, tree_type):
    lst_of_lsts = []
    sm = 0 
    parsed_title = ""
    scope_value = 0.981
    for i in range(0,3):     
        for j in range(0,3):
            for k in range(0,3):
                for l in range(0,3):
                    for n in range(0,3):
                        value = (trained_model.predict_proba([[i,j,k,l,n]]))
                        if i > 0:
                            parsed_title = parsed_title + "BACKLIGHTSUN" 
                        if j > 0:
                            parsed_title = parsed_title + "DARKNESS"
                        if k > 0:
                            parsed_title = parsed_title +  "DIRTLENS"
                        if l > 0:
                            parsed_title = parsed_title +  "MOTIONBLUR"
                        if n > 0:
                            parsed_title = parsed_title + "RAIN"
                        
                        if  numpy.amax(value) != 1:
                        # filter if they are in desired** 
                        
                            lst_of_lsts.append([[i,j,k,l,n], #n], #value, 
                                            numpy.amax(value), 
                                            parsed_title, scope_value,
                                            1- (numpy.amax(value) * scope_value)])
                        
                        sm = sm + numpy.amax(value)
                        parsed_title = ""

    avg_prob = sm/len(lst_of_lsts)
    
    print("AVERAGE OF ALL PROBABILITIES{}".format(avg_prob))
    lst_of_lsts.sort(key=lambda x: x[1], reverse=True)
    
    headers = ['Value', 
              'Pq O = 1', 
               'class_title', 
               'scope',
                'uncertainty (with scope)']
    print(tabulate(lst_of_lsts, headers=headers))
    df = pd.DataFrame(lst_of_lsts, columns=headers)
    df.to_csv(root_directory + "/TSD/RESULTS_{}.csv".format(tree_type))      
calculate_metrics(dt.clf, "DECISION_TREE_WITH_IDEAL_PRUNNING")
ARKNESSDIRTLENSMOTIONBLUR                    0.981                   0.48988
# [0, 1, 2, 2, 1]    0.52      DARKNESSDIRTLENSMOTIONBLURRAIN                0.981                   0.48988
# [0, 2, 2, 2, 0]    0.52      DARKNESSDIRTLENSMOTIONBLUR                    0.981                   0.48988
# [0, 2, 2, 2, 1]    0.52      DARKNESSDIRTLENSMOTIONBLURRAIN                0.981                   0.48988
# [1, 0, 2, 2, 0]    0.52      BACKLIGHTSUNDIRTLENSMOTIONBLUR                0.981                   0.48988
# [1, 0, 2, 2, 1]    0.52      BACKLIGHTSUNDIRTLENSMOTIONBLURRAIN            0.981                   0.48988
# [1, 1, 2, 2, 0]    0.52      BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLUR        0.981                   0.48988
# [1, 1, 2, 2, 1]    0.52      BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLURRAIN    0.981                   0.48988
# [1, 2, 2, 2, 0]    0.52      BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLUR        0.981                   0.48988
# [1, 2, 2, 2, 1]    0.52      BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLURRAIN    0.981                   0.48988
# [[0.03048239 0.96951761]]

# %%
from sklearn.tree import _tree
from sklearn.utils import resample
from matplotlib import pyplot
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.ensemble import AdaBoostClassifier
from IPython.display import Image
from sklearn.externals.six import StringIO
from sklearn.tree import export_graphviz
#import pydot
#import pydot

context_data, X_test, y_test = generate_ds_from_p_file(pickle_file)
ada = AdaBoostClassifier()
tree = ada.fit(context_data['data'], context_data['target'])
y_pred = tree.predict(X_test)



print(len(ada.estimators_))
sub_tree = ada.estimators_[0]
print("Model Accuracy: %.2f" % (accuracy_score(y_test,y_pred)*100), "%")
# Out:
# 50
# Model Accuracy: 85.43 %

# %% [markdown]
# Bagging Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier
tree = DecisionTreeClassifier("entropy")
bag = BaggingClassifier(tree,random_state=1)
context_data, X_test, y_test = generate_ds_from_p_file(pickle_file)
bag.fit(context_data['data'], context_data['target'])
y_pred = bag.predict(X_test)
print("Model Accuracy: %.2f" % (accuracy_score(y_test,y_pred)*100), "%")

calculate_metrics(bag, "BAGGING_CLASSIFER")
# Out:
# Model Accuracy: 85.96 %
# AVERAGE OF ALL PROBABILITIES0.7745625762469546
# Value           Pq O = 1  class_title                                   scope    uncertainty (with scope)
# ------------  ----------  ------------------------------------------  -------  --------------------------
# [0, 1, 2, 0]    0.994792  DARKNESSDIRTLENS                              0.981                   0.0241094
# [1, 0, 2, 1]    0.989659  BACKLIGHTSUNDIRTLENSMOTIONBLUR                0.981                   0.0291447
# [2, 1, 0, 1]    0.988087  BACKLIGHTSUNDARKNESSMOTIONBLUR                0.981                   0.0306864
# [0, 1, 1, 0]    0.987276  DARKNESSDIRTLENSRAIN                          0.981                   0.0314825
# [0, 0, 1, 0]    0.986688  DIRTLENS                                      0.981                   0.0320587
# [1, 0, 2, 0]    0.982759  BACKLIGHTSUNDIRTLENSRAIN                      0.981                   0.0359138
# [1, 0, 1, 1]    0.982732  BACKLIGHTSUNDIRTLENSMOTIONBLURRAIN            0.981                   0.0359395
# [0, 0, 1, 1]    0.981117  DIRTLENSMOTIONBLUR                            0.981                   0.0375244
# [0, 0, 0, 0]    0.976778                                                0.981                   0.0417804
# [1, 0, 1, 2]    0.967096  BACKLIGHTSUNDIRTLENSMOTIONBLURRAIN            0.981                   0.0512792
# [1, 1, 1, 1]    0.966511  BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLURRAIN    0.981                   0.0518523
# [1, 1, 2, 1]    0.966511  BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLURRAIN    0.981                   0.0518523
# [0, 2, 2, 2]    0.963717  DARKNESSDIRTLENSMOTIONBLURRAIN                0.981                   0.0545938
# [1, 2, 2, 2]    0.963717  BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLURRAIN    0.981                   0.0545938
# [0, 1, 0, 0]    0.96323   DARKNESS                                      0.981                   0.0550711
# [0, 0, 2, 0]    0.961661  DIRTLENS                                      0.981                   0.0566106
# [1, 0, 0, 0]    0.96139   BACKLIGHTSUNRAIN                              0.981                   0.0568763
# [1, 1, 1, 2]    0.959804  BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLURRAIN    0.981                   0.0584324
# [0, 0, 2, 1]    0.958543  DIRTLENSMOTIONBLUR                            0.981                   0.0596689
# [1, 1, 0, 0]    0.956063  BACKLIGHTSUNDARKNESS                          0.981                   0.0621025
# [1, 0, 0, 0]    0.954972  BACKLIGHTSUN                                  0.981                   0.0631726
# [1, 0, 0, 1]    0.952756  BACKLIGHTSUNMOTIONBLUR                        0.981                   0.0653462
# [1, 1, 2, 0]    0.949698  BACKLIGHTSUNDARKNESSDIRTLENS                  0.981                   0
BACKLIGHTSUNDARKNESSMOTIONBLURRAIN            0.981                   0.26876
# [2, 1, 1, 1]    0.743182  BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLURRAIN    0.981                   0.270939
# [0, 0, 0, 1]    0.742774  MOTIONBLURRAIN                                0.981                   0.271339
# [2, 0, 2, 0]    0.742241  BACKLIGHTSUNDIRTLENSRAIN                      0.981                   0.271861
# [2, 0, 1, 2]    0.741703  BACKLIGHTSUNDIRTLENSMOTIONBLURRAIN            0.981                   0.27239
# [2, 1, 1, 2]    0.741703  BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLURRAIN    0.981                   0.27239
# [2, 2, 1, 2]    0.741703  BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLURRAIN    0.981                   0.27239
# [2, 1, 2, 0]    0.741668  BACKLIGHTSUNDARKNESSDIRTLENS                  0.981                   0.272423
# [2, 0, 2, 0]    0.739167  BACKLIGHTSUNDIRTLENSRAIN                      0.981                   0.274878
# [0, 1, 1, 0]    0.735967  DARKNESSDIRTLENSRAIN                          0.981                   0.278016
# [1, 1, 1, 0]    0.735967  BACKLIGHTSUNDARKNESSDIRTLENSRAIN              0.981                   0.278016
# [0, 2, 0, 2]    0.727687  DARKNESSMOTIONBLUR                            0.981                   0.286139
# [0, 2, 1, 2]    0.727687  DARKNESSDIRTLENSMOTIONBLUR                    0.981                   0.286139
# [2, 1, 1, 0]    0.725     BACKLIGHTSUNDARKNESSDIRTLENSRAIN              0.981                   0.288775
# [2, 1, 2, 0]    0.725     BACKLIGHTSUNDARKNESSDIRTLENSRAIN              0.981                   0.288775
# [0, 1, 1, 1]    0.719621  DARKNESSDIRTLENSMOTIONBLUR                    0.981                   0.294051
# [2, 0, 2, 0]    0.714839  BACKLIGHTSUNDIRTLENS                          0.981                   0.298743
# [2, 2, 0, 0]    0.710987  BACKLIGHTSUNDARKNESSRAIN                      0.981                   0.302522
# [1, 2, 1, 2]    0.710977  BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLUR        0.981                   0.302532
# [2, 1, 2, 2]    0.71039   BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLURRAIN    0.981                   0.303108
# [0, 1, 2, 2]    0.702381  DARKNESSDIRTLENSMOTIONBLURRAIN                0.981                   0.310964
# [2, 2, 1, 0]    0.700714  BACKLIGHTSUNDARKNESSDIRTLENSRAIN              0.981                   0.312599
# [0, 2, 2, 1]    0.691049  DARKNESSDIRTLENSMOTIONBLUR                    0.981                   0.322081
# [1, 2, 2, 1]    0.691049  BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLUR        0.981                   0.322081
# [2, 1, 0, 0]    0.687185  BACKLIGHTSUNDARKNESSRAIN                      0.981                   0.325872
# [0, 2, 0, 0]    0.685554  DARKNESSRAIN                                  0.981                   0.327471
# [1, 2, 0, 0]    0.685554  BACKLIGHTSUNDARKNESSRAIN                      0.981                   0.327471
# [0, 2, 0, 1]    0.684927  DARKNESSMOTIONBLURRAIN                        0.981                   0.328087
# [0, 0, 0, 2]    0.684327  MOTIONBLURRAIN                                0.981                   0.328675
# [2, 1, 0, 1]    0.682571  BACKLIGHTSUNDARKNESSMOTIONBLURRAIN            0.981                   0.330398
# [2, 0, 0, 0]    0.6825    BACKLIGHTSUNRAIN                              0.981                   0.330468
# [2, 0, 2, 2]    0.677056  BACKLIGHTSUNDIRTLENSMOTIONBLURRAIN            0.981                   0.335808
# [2, 0, 0, 0]    0.676537  BACKLIGHTSUNRAIN                              0.981                   0.336317
# [2, 0, 0, 1]    0.676537  BACKLIGHTSUNMOTIONBLURRAIN                    0.981                   0.336317
# [2, 2, 2, 1]    0.674788  BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLUR        0.981                   0.338033
# [1, 2, 0, 2]    0.672075  BACKLIGHTSUNDARKNESSMOTIONBLUR                0.981                   0.340695
# [2, 1, 0, 0]    0.660916  BACKLIGHTSUNDARKNESSRAIN                      0.981                   0.351641
# [2, 1, 1, 0]    0.659982  BACKLIGHTSUNDARKNESSDIRTLENS                  0.981                   0.352557
# [2, 0, 1, 0]    0.655833  BACKLIGHTSUNDIRTLENSRAIN                      0.981                   0.356628
# [1, 0, 0, 2]    0.655302  BACKLIGHTSUNMOTIONBLURRAIN                    0.981                   0.357149
# [1, 1, 0, 2]    0.655024  BACKLIGHTSUNDARKNESSMOTIONBLURRAIN            0.981                   0.357421
# [0, 2, 2, 2]    0.65      DARKNESSDIRTLENSMOTIONBLURRAIN                0.981                   0.36235
# [2, 1, 1, 0]    0.647967  BACKLIGHTSUNDARKNESSDIRTLENSRAIN              0.981                   0.364344
# [1, 0, 2, 2]    0.647381  BACKLIGHTSUNDIRTLENSMOTIONBLUR                0.981                   0.364919
# [1, 2, 1, 2]    0.646947  BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLURRAIN    0.981                   0.365345
# [2, 0, 0, 2]    0.644206  BACKLIGHTSUNMOTIONBLURRAIN                    0.981                   0.368034
# [2, 1, 0, 2]    0.644206  BACKLIGHTSUNDARKNESSMOTIONBLURRAIN            0.981                   0.368034
# [2, 2, 0, 2]    0.644206  BACKLIGHTSUNDARKNESSMOTIONBLURRAIN            0.981                   0.368034
# [2, 1, 2, 1]    0.643182  BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLURRAIN    0.981                   0.369039
# [2, 2, 1, 0]    0.640471  BACKLIGHTSUNDARKNESSDIRTLENSRAIN              0.981                   0.371698
# [2, 2, 0, 1]    0.634674  BACKLIGHTSUNDARKNESSMOTIONBLURRAIN            0.981                   0.377385
# [0, 1, 2, 2]    0.631977  DARKNESSDIRTLENSMOTIONBLURRAIN                0.981                   0.380031
# [1, 1, 2, 2]    0.631977  BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLURRAIN    0.981                   0.380031
# [2, 2, 0, 1]    0.631117  BACKLIGHTSUNDARKNESSMOTIONBLURRAIN            0.981                   0.380874
# [2, 0, 1, 0]    0.630085  BACKLIGHTSUNDIRTLENS                          0.981                   0.381886
# [0, 1, 2, 0]    0.626744  DARKNESSDIRTLENSRAIN                          0.981                   0.385164
# [1, 1, 2, 0]    0.626744  BACKLIGHTSUNDARKNESSDIRTLENSRAIN              0.981                   0
BACKLIGHTSUNDIRTLENSMOTIONBLURRAIN            0.981                   0.482639
# [0, 2, 0, 2]    0.52378   DARKNESSMOTIONBLURRAIN                        0.981                   0.486171
# [1, 2, 0, 2]    0.52378   BACKLIGHTSUNDARKNESSMOTIONBLURRAIN            0.981                   0.486171
# [2, 1, 0, 2]    0.519939  BACKLIGHTSUNDARKNESSMOTIONBLURRAIN            0.981                   0.48994
# [2, 2, 0, 2]    0.518152  BACKLIGHTSUNDARKNESSMOTIONBLURRAIN            0.981                   0.491692
# [1, 0, 2, 1]    0.516667  BACKLIGHTSUNDIRTLENSMOTIONBLURRAIN            0.981                   0.49315
# [0, 1, 1, 2]    0.514286  DARKNESSDIRTLENSMOTIONBLURRAIN                0.981                   0.495486
# [1, 1, 1, 2]    0.514286  BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLURRAIN    0.981                   0.495486
# [2, 0, 1, 2]    0.514027  BACKLIGHTSUNDIRTLENSMOTIONBLUR                0.981                   0.49574
# [2, 1, 1, 2]    0.514027  BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLUR        0.981                   0.49574
# [2, 2, 1, 2]    0.514027  BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLUR        0.981                   0.49574
# [2, 2, 1, 1]    0.509505  BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLURRAIN    0.981                   0.500175
# [1, 0, 1, 2]    0.501786  BACKLIGHTSUNDIRTLENSMOTIONBLURRAIN            0.981                   0.507748
# [1, 2, 2, 1]    0.50155   BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLURRAIN    0.981                   0.50798

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=100, random_state=0)
context_data, X_test, y_test = generate_ds_from_p_file(pickle_file)
random_forest = model.fit(context_data['data'], context_data['target'])
y_pred = random_forest.predict(X_test)

print("Model Accuracy: %.2f" % (accuracy_score(y_test,y_pred)*100), "%")
calculate_metrics(model, "RANDOM_FOREST")
# Out:
# Model Accuracy: 85.99 %
# AVERAGE OF ALL PROBABILITIES0.7477001661628604
# Value           Pq O = 1  class_title                                   scope    uncertainty (with scope)
# ------------  ----------  ------------------------------------------  -------  --------------------------
# [0, 1, 1, 0]    0.999574  DARKNESSDIRTLENS                              0.981                   0.0194183
# [2, 0, 0, 1]    0.99911   BACKLIGHTSUNMOTIONBLUR                        0.981                   0.0198731
# [1, 0, 1, 0]    0.998344  BACKLIGHTSUNDIRTLENSRAIN                      0.981                   0.0206246
# [1, 1, 1, 0]    0.991002  BACKLIGHTSUNDARKNESSDIRTLENSRAIN              0.981                   0.0278266
# [0, 1, 1, 0]    0.9849    DARKNESSDIRTLENSRAIN                          0.981                   0.0338129
# [1, 0, 1, 1]    0.982555  BACKLIGHTSUNDIRTLENSMOTIONBLURRAIN            0.981                   0.0361139
# [0, 0, 1, 0]    0.98154   DIRTLENS                                      0.981                   0.0371096
# [2, 1, 0, 1]    0.979798  BACKLIGHTSUNDARKNESSMOTIONBLUR                0.981                   0.0388178
# [1, 1, 2, 0]    0.97691   BACKLIGHTSUNDARKNESSDIRTLENSRAIN              0.981                   0.0416511
# [0, 1, 2, 0]    0.975451  DARKNESSDIRTLENSRAIN                          0.981                   0.0430825
# [0, 0, 0, 0]    0.97475                                                 0.981                   0.0437703
# [0, 0, 1, 1]    0.974475  DIRTLENSMOTIONBLUR                            0.981                   0.0440401
# [1, 0, 1, 2]    0.973634  BACKLIGHTSUNDIRTLENSMOTIONBLURRAIN            0.981                   0.0448647
# [1, 0, 2, 1]    0.973496  BACKLIGHTSUNDIRTLENSMOTIONBLUR                0.981                   0.0450008
# [1, 0, 0, 1]    0.970388  BACKLIGHTSUNMOTIONBLUR                        0.981                   0.0480495
# [1, 1, 1, 0]    0.962655  BACKLIGHTSUNDARKNESSDIRTLENS                  0.981                   0.0556353
# [0, 1, 0, 0]    0.961952  DARKNESS                                      0.981                   0.0563247
# [1, 1, 2, 0]    0.961886  BACKLIGHTSUNDARKNESSDIRTLENS                  0.981                   0.0563897
# [1, 1, 0, 0]    0.961798  BACKLIGHTSUNDARKNESS                          0.981                   0.056476
# [0, 0, 2, 0]    0.961648  DIRTLENS                                      0.981                   0.0566231
# [0, 1, 2, 0]    0.959628  DARKNESSDIRTLENS                              0.981                   0.0586045
# [1, 0, 1, 0]    0.954716  BACKLIGHTSUNDIRTLENSRAIN                      0.981                   0.0634235
# [1, 0, 0, 0]    0.952748  BACKLIGHTSUN                                  0.981                   0.065354
# [0, 0, 0, 1]    0.950635  MOTIONBLUR                                    0.981                   0.0674266
# [0, 2, 2, 2]    0.949885  DARKNESSDIRTLENSMOTIONBLURRAIN                0.981                   0.0681626
# [0, 0, 2, 1]    0.94841   DIRTLENSMOTIONBLURRAIN                        0.981                   0.0696095
# [1, 1, 1, 1]    0.946629  BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLUR        0.981                   0.071357
# [1, 1, 0, 1]    0.946527  BACKLIGHTSUNDARKNESSMOTIONBLUR                0.981                   0
BACKLIGHTSUNDARKNESSDIRTLENS                  0.981                   0.284424
# [1, 2, 2, 0]    0.727412  BACKLIGHTSUNDARKNESSDIRTLENS                  0.981                   0.286409
# [1, 0, 2, 1]    0.727134  BACKLIGHTSUNDIRTLENSMOTIONBLURRAIN            0.981                   0.286682
# [0, 1, 0, 2]    0.725597  DARKNESSMOTIONBLURRAIN                        0.981                   0.288189
# [0, 2, 0, 2]    0.723072  DARKNESSMOTIONBLUR                            0.981                   0.290666
# [2, 2, 2, 1]    0.72232   BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLUR        0.981                   0.291404
# [2, 2, 0, 1]    0.720181  BACKLIGHTSUNDARKNESSMOTIONBLURRAIN            0.981                   0.293503
# [2, 1, 0, 1]    0.718322  BACKLIGHTSUNDARKNESSMOTIONBLURRAIN            0.981                   0.295327
# [2, 2, 0, 0]    0.715343  BACKLIGHTSUNDARKNESSRAIN                      0.981                   0.298249
# [1, 2, 1, 2]    0.714059  BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLURRAIN    0.981                   0.299508
# [1, 2, 0, 0]    0.714     BACKLIGHTSUNDARKNESSRAIN                      0.981                   0.299566
# [2, 2, 1, 2]    0.7118    BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLURRAIN    0.981                   0.301725
# [2, 0, 0, 2]    0.709298  BACKLIGHTSUNMOTIONBLURRAIN                    0.981                   0.304179
# [2, 1, 0, 0]    0.709285  BACKLIGHTSUNDARKNESSRAIN                      0.981                   0.304191
# [0, 2, 0, 1]    0.708947  DARKNESSMOTIONBLURRAIN                        0.981                   0.304523
# [1, 1, 0, 2]    0.706597  BACKLIGHTSUNDARKNESSMOTIONBLURRAIN            0.981                   0.306828
# [2, 0, 2, 0]    0.701846  BACKLIGHTSUNDIRTLENS                          0.981                   0.311489
# [2, 1, 2, 2]    0.694549  BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLURRAIN    0.981                   0.318647
# [2, 1, 0, 2]    0.689906  BACKLIGHTSUNDARKNESSMOTIONBLURRAIN            0.981                   0.323202
# [0, 2, 0, 0]    0.68729   DARKNESSRAIN                                  0.981                   0.325768
# [0, 0, 0, 2]    0.685201  MOTIONBLURRAIN                                0.981                   0.327818
# [2, 2, 1, 2]    0.682186  BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLURRAIN    0.981                   0.330775
# [1, 1, 0, 2]    0.679996  BACKLIGHTSUNDARKNESSMOTIONBLUR                0.981                   0.332924
# [1, 1, 1, 2]    0.679854  BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLURRAIN    0.981                   0.333063
# [2, 1, 2, 1]    0.67927   BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLUR        0.981                   0.333637
# [0, 2, 2, 0]    0.678682  DARKNESSDIRTLENS                              0.981                   0.334213
# [2, 2, 2, 0]    0.676967  BACKLIGHTSUNDARKNESSDIRTLENS                  0.981                   0.335895
# [0, 2, 2, 0]    0.674105  DARKNESSDIRTLENSRAIN                          0.981                   0.338703
# [2, 2, 2, 1]    0.673287  BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLURRAIN    0.981                   0.339505
# [2, 2, 2, 0]    0.672855  BACKLIGHTSUNDARKNESSDIRTLENSRAIN              0.981                   0.339929
# [2, 2, 2, 0]    0.672486  BACKLIGHTSUNDARKNESSDIRTLENSRAIN              0.981                   0.340291
# [1, 2, 0, 2]    0.670206  BACKLIGHTSUNDARKNESSMOTIONBLUR                0.981                   0.342528
# [2, 2, 1, 1]    0.669579  BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLURRAIN    0.981                   0.343143
# [0, 2, 2, 1]    0.669548  DARKNESSDIRTLENSMOTIONBLURRAIN                0.981                   0.343173
# [2, 2, 0, 2]    0.669     BACKLIGHTSUNDARKNESSMOTIONBLUR                0.981                   0.343711
# [1, 0, 2, 0]    0.667835  BACKLIGHTSUNDIRTLENSRAIN                      0.981                   0.344854
# [1, 2, 1, 1]    0.663874  BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLURRAIN    0.981                   0.34874
# [2, 0, 2, 0]    0.66206   BACKLIGHTSUNDIRTLENSRAIN                      0.981                   0.350519
# [0, 2, 2, 2]    0.660805  DARKNESSDIRTLENSMOTIONBLURRAIN                0.981                   0.35175
# [2, 0, 2, 2]    0.656406  BACKLIGHTSUNDIRTLENSMOTIONBLURRAIN            0.981                   0.356065
# [1, 1, 2, 1]    0.651975  BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLUR        0.981                   0.360413
# [1, 0, 2, 2]    0.650908  BACKLIGHTSUNDIRTLENSMOTIONBLUR                0.981                   0.36146
# [0, 1, 2, 1]    0.650307  DARKNESSDIRTLENSMOTIONBLUR                    0.981                   0.362049
# [0, 2, 1, 2]    0.64774   DARKNESSDIRTLENSMOTIONBLURRAIN                0.981                   0.364567
# [2, 1, 0, 2]    0.647732  BACKLIGHTSUNDARKNESSMOTIONBLUR                0.981                   0.364575
# [2, 0, 0, 0]    0.645897  BACKLIGHTSUNRAIN                              0.981                   0.366375
# [2, 1, 2, 1]    0.644169  BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLURRAIN    0.981                   0.368071
# [0, 2, 2, 1]    0.64243   DARKNESSDIRTLENSMOTIONBLUR                    0.981                   0.369777
# [1, 1, 2, 0]    0.642169  BACKLIGHTSUNDARKNESSDIRTLENSRAIN              0.981                   0.370033
# [2, 0, 1, 0]    0.64022   BACKLIGHTSUNDIRTLENS                          0.981                   0.371944
# [1, 2, 2, 1]    0.639753  BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLURRAIN    0.981                   0.372402
# [2, 2, 1, 0]    0.636118  BACKLIGHTSUNDARKNESSDIRTLENSRAIN              0.981                   0.375969
# [0, 2, 1, 1]    0.629697  DARKNESSDIRTLENSMOTIONBLURRAIN                0.981                   0.382268
# [0, 1, 1, 2]    0.628911  DARKNESSDIRTLENSMOTIONBLURRAIN                0.981                   0.383039
# [2, 1, 1, 1]    0.617676  BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLURRAIN    0.981                   0.39406
# [1, 0, 1, 2]    0.617402  BACKLIGHTSUNDIRTLENSMOTIONBLURRAIN            0.981                   0.394328
# [0, 2, 2, 0]    0.617027  DARKNESSDIRTLENSRAIN                          0.981                   0.394696
# [0, 1, 2, 2]    0.616089  DARKNESSDIRTLENSMOTIONBLURRAIN                0.981                   0.395617
# [2, 1, 1, 1]    0.613558  BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLURRAIN    0.981                   0.3981
# [0, 1, 2, 0]    0.612459  DARKNESSDIRTLENSRAIN                          0.981                   0.399178
# [0, 0, 0, 0]    0.608471  RAIN                                          0.981                   0.40309
# [2, 0, 0, 2]    0.602818  BACKLIGHTSUNMOTIONBLUR                        0.981                   0.408635
# [1, 2, 2, 0]    0.601745  BACKLIGHTSUNDARKNESSDIRTLENSRAIN              0.981                   0.409688
# [2, 2, 1, 0]    0.60067   BACKLIGHTSUNDARKNESSDIRTLENSRAIN              0.981                   0.410743
# [2, 2, 1, 2]    0.599999  BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLUR        0.981                   0.411401
# [1, 2, 2, 1]    0.596359  BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLURRAIN    0.981                   0.414972
# [2, 1, 1, 0]    0.594924  BACKLIGHTSUNDARKNESSDIRTLENSRAIN              0.981                   0.416379
# [1, 2, 2, 0]    0.593747  BACKLIGHTSUNDARKNESSDIRTLENSRAIN              0.981                   0.417534
# [2, 1, 1, 0]    0.59241   BACKLIGHTSUNDARKNESSDIRTLENSRAIN              0.981                   0.418846
# [0, 1, 2, 2]    0.578822  DARKNESSDIRTLENSMOTIONBLUR                    0.981                   0.432175
# [2, 2, 0, 2]    0.577983  BACKLIGHTSUNDARKNESSMOTIONBLURRAIN            0.981                   0.432999
# [1, 2, 0, 2]    0.574246  BACKLIGHTSUNDARKNESSMOTIONBLURRAIN            0.981                   0.436665
# [2, 1, 0, 2]    0.570409  BACKLIGHTSUNDARKNESSMOTIONBLURRAIN            0.981                   0.440429
# [2, 1, 2, 0]    0.568469  BACKLIGHTSUNDARKNESSDIRTLENSRAIN              0.981                   0.442332
# [2, 1, 2, 2]    0.568233  BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLUR        0.981                   0.442563
# [1, 2, 2, 2]    0.565802  BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLURRAIN    0.981                   0.444948
# [0, 2, 0, 1]    0.565767  DARKNESSMOTIONBLURRAIN                        0.981                   0.444982
# [1, 1, 2, 2]    0.565549  BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLUR        0.981                   0.445197
# [2, 0, 2, 0]    0.563057  BACKLIGHTSUNDIRTLENSRAIN                      0.981                   0.447641
# [2, 2, 0, 0]    0.563016  BACKLIGHTSUNDARKNESSRAIN                      0.981                   0.447681
# [1, 2, 2, 2]    0.562262  BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLUR        0.981                   0.448421
# [0, 1, 2, 1]    0.561155  DARKNESSDIRTLENSMOTIONBLURRAIN                0.981                   0.449507
# [2, 2, 0, 1]    0.560123  BACKLIGHTSUNDARKNESSMOTIONBLURRAIN            0.981                   0.45052
# [0, 0, 2, 2]    0.557662  DIRTLENSMOTIONBLURRAIN                        0.981                   0.452933
# [2, 1, 2, 0]    0.556544  BACKLIGHTSUNDARKNESSDIRTLENSRAIN              0.981                   0.45403
# [2, 1, 2, 2]    0.556386  BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLURRAIN    0.981                   0.454185
# [2, 1, 2, 1]    0.554942  BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLURRAIN    0.981                   0.455601
# [0, 0, 2, 0]    0.554679  DIRTLENSRAIN                                  0.981                   0.45586
# [0, 2, 2, 1]    0.551826  DARKNESSDIRTLENSMOTIONBLURRAIN                0.981                   0.458659
# [2, 0, 1, 2]    0.544995  BACKLIGHTSUNDIRTLENSMOTIONBLURRAIN            0.981                   0.46536
# [2, 0, 2, 2]    0.544458  BACKLIGHTSUNDIRTLENSMOTIONBLUR                0.981                   0.465887
# [1, 0, 0, 2]    0.543162  BACKLIGHTSUNMOTIONBLUR                        0.981                   0.467158
# [1, 2, 0, 2]    0.542638  BACKLIGHTSUNDARKNESSMOTIONBLURRAIN            0.981                   0.467672
# [2, 2, 2, 2]    0.541498  BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLURRAIN    0.981                   0.46879
# [2, 0, 0, 1]    0.537202  BACKLIGHTSUNMOTIONBLURRAIN                    0.981                   0.473005
# [2, 0, 0, 2]    0.537109  BACKLIGHTSUNMOTIONBLURRAIN                    0.981                   0.473097
# [2, 1, 1, 2]    0.537092  BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLURRAIN    0.981                   0.473113
# [0, 1, 2, 2]    0.536896  DARKNESSDIRTLENSMOTIONBLURRAIN                0.981                   0.473305
# [2, 0, 2, 1]    0.532642  BACKLIGHTSUNDIRTLENSMOTIONBLURRAIN            0.981                   0.477478
# [2, 2, 2, 1]    0.530965  BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLURRAIN    0.981                   0.479124
# [2, 2, 2, 2]    0.528718  BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLUR        0.981                   0.481328
# [0, 0, 2, 2]    0.527405  DIRTLENSMOTIONBLUR                            0.981                   0.482615
# [2, 0, 1, 1]    0.527247  BACKLIGHTSUNDIRTLENSMOTIONBLURRAIN            0.981                   0.48277
# [2, 1, 0, 0]    0.526747  BACKLIGHTSUNDARKNESSRAIN                      0.981                   0.483261
# [1, 1, 2, 2]    0.524833  BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLURRAIN    0.981                   0.485139
# [0, 2, 0, 2]    0.523741  DARKNESSMOTIONBLURRAIN                        0.981                   0.48621
# [1, 1, 2, 1]    0.522834  BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLURRAIN    0.981                   0.4871
# [2, 1, 1, 2]    0.521779  BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLUR        0.981                   0.488135
# [2, 0, 1, 2]    0.519616  BACKLIGHTSUNDIRTLENSMOTIONBLUR                0.981                   0.490256
# [2, 0, 1, 1]    0.51925   BACKLIGHTSUNDIRTLENSMOTIONBLURRAIN            0.981                   0.490616
# [0, 2, 0, 2]    0.51745   DARKNESSMOTIONBLURRAIN                        0.981                   0.492382
# [2, 2, 1, 1]    0.51657   BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLURRAIN    0.981                   0.493245
# [0, 2, 2, 2]    0.511624  DARKNESSDIRTLENSMOTIONBLUR                    0.981                   0.498097
# [0, 0, 1, 2]    0.508366  DIRTLENSMOTIONBLURRAIN                        0.981                   0.501292
# [0, 0, 2, 1]    0.503831  DIRTLENSMOTIONBLURRAIN                        0.981                   0.505742
# [1, 2, 0, 1]    0.502093  BACKLIGHTSUNDARKNESSMOTIONBLURRAIN            0.981                   0.507446
# [1, 0, 2, 2]    0.500901  BACKLIGHTSUNDIRTLENSMOTIONBLURRAIN            0.981                   0.508617
# [2, 2, 0, 2]    0.500656  BACKLIGHTSUNDARKNESSMOTIONBLURRAIN            0.981                   0.508857
# [1, 1, 2, 2]    0.500134  BACKLIGHTSUNDARKNESSDIRTLENSMOTIONBLURRAIN    0.981                   0.509369

# %%
from sklearn.tree._tree import TREE_LEAF

def prune_index(inner_tree, index, threshold):
    if inner_tree.value[index].min() < threshold:
        # turn node into a leaf by "unlinking" its children
        inner_tree.children_left[index] = TREE_LEAF
        inner_tree.children_right[index] = TREE_LEAF
    # if there are shildren, visit them as well
    if inner_tree.children_left[index] != TREE_LEAF:
        prune_index(inner_tree, inner_tree.children_left[index], threshold)
        prune_index(inner_tree, inner_tree.children_right[index], threshold)


print(sum(dt.clf.tree_.children_left < 0))
# start pruning from the root
prune_index(dt.clf.tree_, 0, 800)
print(sum(dt.clf.tree_.children_left < 0))
dt.display_image("pruned_tree_1.pdf")
# Out:
# 121
# 125

# %% [markdown]
# # Random Forest Classifier

# %%
# Load libraries
import matplotlib.pyplot as plt
import numpy as np
from sklearn.datasets import load_digits
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import validation_curve

# Load data
digits = load_digits()

# Create feature matrix and target vector
X, y = digits.data, digits.target

context_data, X_test, y_test = generate_ds_from_p_file(pickle_file)
X = context_data['data']
y = context_data['target']

param_range = np.arange(1, 250, 2)

train_scores, test_scores = validation_curve(RandomForestClassifier(), 
                                             X, 
                                             y, 
                                             param_name="n_estimators", 
                                             param_range=param_range,
                                             cv=3, 
                                             scoring="accuracy", 
                                             n_jobs=-1)


train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)

# Calculate mean and standard deviation for test set scores
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

# %%
# Plot mean accuracy scores for training and test sets
plt.plot(param_range, train_mean, label="Training score", color="black")
plt.plot(param_range, test_mean, label="Cross-validation score", color="dimgrey")

# Plot accurancy bands for training and test sets
plt.fill_between(param_range, train_mean - train_std, train_mean + train_std, color="gray")
plt.fill_between(param_range, test_mean - test_std, test_mean + test_std, color="gainsboro")

# Create plot
plt.title("Validation Curve With Random Forest")
plt.xlabel("Number Of Trees")
plt.ylabel("Accuracy Score")
plt.tight_layout()
plt.legend(loc="best")
plt.show();
